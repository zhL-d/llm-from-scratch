# %% [markdown]
# # Problem (generate):  Generate text

# %%
UV_NO_SYNC=1 uv run python cs336_basics/generate.py

# %% [markdown]
# ```
# generated_text[0]: Once upon a time, there was a little girl named Sue. Sue had a big, red ball. She loved to play with her ball. One day, she saw her ball in the park. Sue was very happy.
# Sue kicked the ball very hard. The ball went very high and far. It went up, up, up. Sue was very happy. She wanted to catch the ball. But then, something unexpected happened.
# Sue saw her ball. She kicked the ball very hard. The ball went into the air and landed on a big tree. The tree had a surprise. The tree was a surprise! It was a big, colorful bird. The bird had the ball in its beak. Sue was so happy! She thanked the bird and played with her new friend.
# <|endoftext|>
